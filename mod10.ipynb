# %%
import pandas as pd

# %%
df = pd.read_excel('County-table1A.xlsx')
df
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1
# 2                                 State/Jurisdiction
# 3
# 4                                           Maryland
# 5
# 6                                   Baltimore Region
# 7                                      Anne Arundel
# 8                                         Baltimore
# 9                                           Carroll
# 10                                          Harford
# 11                                           Howard
# 12                                    Baltimore City
# 13
# 14                        Suburban Washington Region
# 15                                        Frederick
# 16                                       Montgomery
# 17                                  Prince George's
# 18
# 19                          Southern Maryland Region
# 20                                          Calvert
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 14 columns):
#  #   Column                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                              --------------  -----
#  0   Unnamed: 0                                                                                          44 non-null     object
#  1   Table 1A.  Total Resident Population for Maryland's Jurisdictions, April 1, 2010 Thru July 1, 2020  34 non-null     object
#  2   Unnamed: 2                                                                                          34 non-null     object
#  3   Unnamed: 3                                                                                          34 non-null     object
# ...

# %%
md = df[['Unnamed: 0', 'Unnamed: 13']].iloc[7:41].drop_duplicates()
md = md.rename(columns={'Unnamed: 0': 'County', 'Unnamed: 13': 'Popuation'})
md['County'] = md['County'].str.strip()
md.drop_duplicates()
md.to_csv('population_md.csv',index = False)

# %% [markdown]
# loc[9:14, 17:19, 22:24, 27:29, 32:36, 39:42]
